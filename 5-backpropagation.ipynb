# %% [markdown]
# ![Jepretan Layar 2023-10-11 pukul 09.07.46.png](data:image/png;base64,...)

# %% [markdown]
# ![Jepretan Layar 2023-10-11 pukul 09.09.38.png](data:image/png;base64,...)

# %% [markdown]
# ![Jepretan Layar 2023-10-11 pukul 09.16.11.png](data:image/png;base64,...)
