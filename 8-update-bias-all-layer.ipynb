# %% [markdown]
# ![Jepretan Layar 2023-11-16 pukul 17.11.32.png](data:image/png;base64,...)

# %% [markdown]
# ![Jepretan Layar 2023-11-16 pukul 17.11.59.png](data:image/png;base64,...)

# %% [markdown]
# ![Jepretan Layar 2023-11-16 pukul 17.12.34.png](data:image/png;base64,...)
