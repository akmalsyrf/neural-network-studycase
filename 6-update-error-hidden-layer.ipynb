# %% [markdown]
# ![Jepretan Layar 2023-11-16 pukul 16.39.27.png](data:image/png;base64,...)

# %% [markdown]
# ![Jepretan Layar 2023-11-16 pukul 16.40.49.png](data:image/png;base64,...)

# %% [markdown]
# ![Jepretan Layar 2023-11-16 pukul 16.47.20.png](data:image/png;base64,...)

# %% [markdown]
# ![Jepretan Layar 2023-11-16 pukul 16.48.37.png](data:image/png;base64,...)
